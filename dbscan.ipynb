# %% [markdown]
# # DBScan.ipynb
# Separates outliers as an idiomatic construction

# %%
#parameters
inputFile = 'ki-diff.tsv'          # input file name (.tsv) 
outputFile = 'ki-diff-dbscan.tsv'  # output: compositional constructions
outputFile2 = 'ki-diff-idioms.tsv' # output: idiomatic constructions
# change 'ki' to 'el' for the other dataset!

# %%
import pandas as pd
from sklearn.cluster import DBSCAN

# %%
# reading input data
data = pd.read_csv(inputFile, sep='\t')
data
# Out:
#    pvform   lemma        pvv mood cau pot        PV    CP_cnd    CP_imp  \
# 0      ki      ad      ki+ad  ind   -   + -0.646132 -0.011485  0.002283
# 1      ki      ad      ki+ad  ind   -   - -0.682139  0.003061  0.003940
# 2      ki  alakít  ki+alakít  ind   -   - -0.805568  0.000722  0.001324
# 3      ki  alakul  ki+alakul  ind   -   + -0.529124 -0.006371  0.001324
# 4      ki  alakul  ki+alakul  ind   -   - -0.815422 -0.001371 -0.001357
# ..    ...     ...        ...  ...  ..  ..       ...       ...       ...
# 91     ki  veszik  ki+veszik  ind   -   - -0.168734 -0.012407 -0.008685
# 92     ki     vet     ki+vet  ind   -   - -0.704976 -0.003374 -0.002327
# 93     ki    visz    ki+visz  ind   -   - -0.429151 -0.000944  0.000057
# 94     ki     von     ki+von  ind   -   - -0.490433 -0.003047  0.000509
# 95     ki     zár     ki+zár  ind   -   - -0.397045 -0.008993  0.001436
#
#       CP_ind  ...       ÉRT      KÉNT       KOR      SZOR     NKÉNT       ADP  \
# 0  -0.015521  ... -0.002910 -0.006208  0.001593  0.000000 -0.001194 -0.046572
# 1  -0.031520  ...  0.010284 -0.004983  0.001106  0.000293  0.001097 -0.060067
# 2   0.069808  ... -0.000077 -0.003117 -0.001809 -0.000145 -0.000649 -0.083350
# 3  -0.009999  ... -0.000725  0.002790  0.000717  0.000000  0.004789  0.264358
# 4  -0.052024  ... -0.001153 -0.005363 -0.001899  0.000000  0.001351  0.247248
# ..       ...  ...       ...       ...       ...       ...       ...       ...
# 91  0.073525  ... -0.002481 -0.003722 -0.002481  0.000000  0.039756  0.191391
# 92 -0.020252  ... -0.002110 -0.004526 -0.000046  0.000000 -0.008850 -0.004577
# 93 -0.035104  ...  0.001402 -0.003614 -0.004179  0.000000 -0.001563  0.028151
# 94  0.014885  ...  0.012652 -0.003047 -0.000789  0.000000  0.000926  0.093215
# 95  0.068823  ...  0.000768  0.008984  0.036043  0.000000  0.001595  0.000464
#
#          ADV      FROM        IN        TO
# 0  -0.048491  0.008707 -0.109183  0.195846
# 1  -0.024275  0.007954 -0.154583  0.082377
# 2  -0.016421 -0.052144 -0.176042 -0.033550
# 3   0.047572 -0.034485  0.115629 -0.007977
# 4   0.177070 -0.044549  0.046432 -0.019576
# ..       ...       ...       ...       ...
# 91 -0.107671 -0.420542  0.083396  0.401284
# 92  0.005294 -0.039473 -0.069410  0.093608
# 93  0.038024 -0.174115 -0.004423  0.009901
# 94 -0.051066 -0.783797  0.043289  0.378963
# 95  0.053622 -0.230176  0.081207  0.150297
#
# [96 rows x 38 columns]

# %%
# geting the difference vectors
x = data.iloc[:,6:] 
x
# Out:
#           PV    CP_cnd    CP_imp    CP_ind       HKM       inf       nom  \
# 0  -0.646132 -0.011485  0.002283 -0.015521  0.089213  0.000696  0.063584
# 1  -0.682139  0.003061  0.003940 -0.031520  0.073813  0.012231 -0.022146
# 2  -0.805568  0.000722  0.001324  0.069808 -0.036497  0.001268  0.309068
# 3  -0.529124 -0.006371  0.001324 -0.009999 -0.000635 -0.001684 -0.082512
# 4  -0.815422 -0.001371 -0.001357 -0.052024 -0.045779 -0.000886 -0.052194
# ..       ...       ...       ...       ...       ...       ...       ...
# 91 -0.168734 -0.012407 -0.008685  0.073525 -0.031017 -0.004963 -0.103733
# 92 -0.704976 -0.003374 -0.002327 -0.020252  0.101386 -0.000191 -0.051201
# 93 -0.429151 -0.000944  0.000057 -0.035104 -0.003547 -0.006377  0.104916
# 94 -0.490433 -0.003047  0.000509  0.014885  0.054230  0.001346  0.176474
# 95 -0.397045 -0.008993  0.001436  0.068823 -0.229059  0.000309  0.140059
#
#          acc       dat       BAN  ...       ÉRT      KÉNT       KOR      SZOR  \
# 0   0.083833  0.119385 -0.049676  ... -0.002910 -0.006208  0.001593  0.000000
# 1   0.097859  0.126506 -0.089909  ...  0.010284 -0.004983  0.001106  0.000293
# 2  -0.072415 -0.012997 -0.030790  ... -0.000077 -0.003117 -0.001809 -0.000145
# 3  -0.000106 -0.000125  0.016273  ... -0.000725  0.002790  0.000717  0.000000
# 4  -0.002312 -0.007125 -0.072296  ... -0.001153 -0.005363 -0.001899  0.000000
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 91  0.464937  0.034793  0.023681  ... -0.002481 -0.003722 -0.002481  0.000000
# 92 -0.058149  0.210011 -0.030242  ... -0.002110 -0.004526 -0.000046  0.000000
# 93  0.064053  0.000636 -0.013936  ...  0.001402 -0.003614 -0.004179  0.000000
# 94 -0.165672  0.011346 -0.085834  ...  0.012652 -0.003047 -0.000789  0.000000
# 95  0.103732  0.001207  0.014062  ...  0.000768  0.008984  0.036043  0.000000
#
#        NKÉNT       ADP       ADV      FROM        IN        TO
# 0  -0.001194 -0.046572 -0.048491  0.008707 -0.109183  0.195846
# 1   0.001097 -0.060067 -0.024275  0.007954 -0.154583  0.082377
# 2  -0.000649 -0.083350 -0.016421 -0.052144 -0.176042 -0.033550
# 3   0.004789  0.264358  0.047572 -0.034485  0.115629 -0.007977
# 4   0.001351  0.247248  0.177070 -0.044549  0.046432 -0.019576
# ..       ...       ...       ...       ...       ...       ...
# 91  0.039756  0.191391 -0.107671 -0.420542  0.083396  0.401284
# 92 -0.008850 -0.004577  0.005294 -0.039473 -0.069410  0.093608
# 93 -0.001563  0.028151  0.038024 -0.174115 -0.004423  0.009901
# 94  0.000926  0.093215 -0.051066 -0.783797  0.043289  0.378963
# 95  0.001595  0.000464  0.053622 -0.230176  0.081207  0.150297
#
# [96 rows x 32 columns]

# %%
for M in range(2,5): # number of neighbours
    for Rint in range(100, 200):
        R = Rint/200 # maximal distance of neighbours
        db = DBSCAN(eps=R, min_samples=M)
        db.fit(x)
        labels = db.labels_

        
        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0) # Number of clusters
        n_outl_ = list(labels).count(-1) # number of outliers

        print(f"R={R}\t M={M} \t clusters:{n_clusters_} \t outliers:{n_outl_}", end='\t')
        if n_outl_ < 20:
            print(list(data[labels == -1]["pvv"]))
        else:
            print('')
# Out:
# R=0.5	 M=2 	 clusters:3 	 outliers:27
# R=0.505	 M=2 	 clusters:3 	 outliers:26
# R=0.51	 M=2 	 clusters:3 	 outliers:26
# R=0.515	 M=2 	 clusters:3 	 outliers:26
# R=0.52	 M=2 	 clusters:3 	 outliers:25
# R=0.525	 M=2 	 clusters:4 	 outliers:21
# R=0.53	 M=2 	 clusters:3 	 outliers:20
# R=0.535	 M=2 	 clusters:3 	 outliers:20
# R=0.54	 M=2 	 clusters:3 	 outliers:18	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+nő', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.545	 M=2 	 clusters:3 	 outliers:18	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+nő', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.55	 M=2 	 clusters:3 	 outliers:17	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.555	 M=2 	 clusters:3 	 outliers:17	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.56	 M=2 	 clusters:3 	 outliers:16	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.565	 M=2 	 clusters:2 	 outliers:16	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.57	 M=2 	 clusters:2 	 outliers:14	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.575	 M=2 	 clusters:2 	 outliers:13	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.58	 M=2 	 clusters:2 	 outliers:12	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik']
# R=0.585	 M=2 	 clusters:1 	 outliers:12	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik']
# R=0.59	 M=2 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.595	 M=2 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.6	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.605	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.61	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.615	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.62	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.625	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.63	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.635	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.64	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.645	 M=2 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.65	 M=2 	 clusters:1 	 outliers:8	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.655	 M=2 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.66	 M=2 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.665	 M=2 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.67	 M=2 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.675	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.68	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.685	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.69	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.695	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.7	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.705	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.71	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.715	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.72	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.725	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.73	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.735	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.74	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.745	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.75	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.755	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.76	 M=2 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.765	 M=2 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.77	 M=2 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.775	 M=2 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.78	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.785	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.79	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.795	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.8	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.805	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.81	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.815	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.82	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.825	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.83	 M=2 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.835	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.84	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.845	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.85	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.855	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.86	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.865	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.87	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.875	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.88	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.885	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.89	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.895	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.9	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.905	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.91	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.915	 M=2 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.92	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.925	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.93	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.935	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.94	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.945	 M=2 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.95	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.955	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.96	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.965	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.97	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.975	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.98	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.985	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.99	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.995	 M=2 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.5	 M=3 	 clusters:2 	 outliers:29
# R=0.505	 M=3 	 clusters:2 	 outliers:28
# R=0.51	 M=3 	 clusters:2 	 outliers:28
# R=0.515	 M=3 	 clusters:2 	 outliers:28
# R=0.52	 M=3 	 clusters:2 	 outliers:27
# R=0.525	 M=3 	 clusters:2 	 outliers:25
# R=0.53	 M=3 	 clusters:2 	 outliers:22
# R=0.535	 M=3 	 clusters:2 	 outliers:22
# R=0.54	 M=3 	 clusters:2 	 outliers:20
# R=0.545	 M=3 	 clusters:2 	 outliers:20
# R=0.55	 M=3 	 clusters:2 	 outliers:19	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.555	 M=3 	 clusters:2 	 outliers:19	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+fejez', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.56	 M=3 	 clusters:2 	 outliers:18	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.565	 M=3 	 clusters:1 	 outliers:18	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.57	 M=3 	 clusters:1 	 outliers:16	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.575	 M=3 	 clusters:1 	 outliers:15	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.58	 M=3 	 clusters:1 	 outliers:14	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik']
# R=0.585	 M=3 	 clusters:1 	 outliers:12	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik']
# R=0.59	 M=3 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.595	 M=3 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.6	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.605	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.61	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.615	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.62	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.625	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.63	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.635	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.64	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.645	 M=3 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.65	 M=3 	 clusters:1 	 outliers:8	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.655	 M=3 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.66	 M=3 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.665	 M=3 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.67	 M=3 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.675	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.68	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.685	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.69	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.695	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.7	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.705	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.71	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.715	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.72	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.725	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.73	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.735	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.74	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.745	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.75	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.755	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.76	 M=3 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.765	 M=3 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.77	 M=3 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.775	 M=3 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.78	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.785	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.79	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.795	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.8	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.805	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.81	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.815	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.82	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.825	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.83	 M=3 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.835	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.84	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.845	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.85	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.855	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.86	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.865	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.87	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.875	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.88	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.885	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.89	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.895	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.9	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.905	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.91	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.915	 M=3 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.92	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.925	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.93	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.935	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.94	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.945	 M=3 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.95	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.955	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.96	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.965	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.97	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.975	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.98	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.985	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.99	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.995	 M=3 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.5	 M=4 	 clusters:2 	 outliers:30
# R=0.505	 M=4 	 clusters:2 	 outliers:29
# R=0.51	 M=4 	 clusters:2 	 outliers:29
# R=0.515	 M=4 	 clusters:2 	 outliers:28
# R=0.52	 M=4 	 clusters:2 	 outliers:27
# R=0.525	 M=4 	 clusters:2 	 outliers:26
# R=0.53	 M=4 	 clusters:2 	 outliers:24
# R=0.535	 M=4 	 clusters:2 	 outliers:24
# R=0.54	 M=4 	 clusters:2 	 outliers:22
# R=0.545	 M=4 	 clusters:2 	 outliers:22
# R=0.55	 M=4 	 clusters:2 	 outliers:20
# R=0.555	 M=4 	 clusters:2 	 outliers:20
# R=0.56	 M=4 	 clusters:2 	 outliers:19	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tör', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.565	 M=4 	 clusters:1 	 outliers:19	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+ír', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+számít', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tör', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.57	 M=4 	 clusters:1 	 outliers:17	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+néz', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tör', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.575	 M=4 	 clusters:1 	 outliers:16	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tör', 'ki+tűnik', 'ki+veszik', 'ki+von']
# R=0.58	 M=4 	 clusters:1 	 outliers:15	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+dolgoz', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tör', 'ki+tűnik', 'ki+veszik']
# R=0.585	 M=4 	 clusters:1 	 outliers:13	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tesz', 'ki+tűnik', 'ki+veszik']
# R=0.59	 M=4 	 clusters:1 	 outliers:12	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.595	 M=4 	 clusters:1 	 outliers:12	['ki+bocsát', 'ki+derül', 'ki+dolgozik', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.6	 M=4 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.605	 M=4 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.61	 M=4 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.615	 M=4 	 clusters:1 	 outliers:11	['ki+bocsát', 'ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.62	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.625	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.63	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.635	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.64	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.645	 M=4 	 clusters:1 	 outliers:10	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+tart', 'ki+terjed', 'ki+tűnik', 'ki+veszik']
# R=0.65	 M=4 	 clusters:1 	 outliers:8	['ki+derül', 'ki+egészül', 'ki+indul', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.655	 M=4 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.66	 M=4 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.665	 M=4 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.67	 M=4 	 clusters:1 	 outliers:7	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed', 'ki+tűnik']
# R=0.675	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.68	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.685	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.69	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.695	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.7	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.705	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.71	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.715	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.72	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.725	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.73	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.735	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.74	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.745	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.75	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.755	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.76	 M=4 	 clusters:1 	 outliers:6	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+merül', 'ki+terjed']
# R=0.765	 M=4 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.77	 M=4 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.775	 M=4 	 clusters:1 	 outliers:5	['ki+derül', 'ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.78	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.785	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.79	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.795	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.8	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.805	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.81	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.815	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.82	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.825	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.83	 M=4 	 clusters:1 	 outliers:4	['ki+egészül', 'ki+kap', 'ki+köt', 'ki+terjed']
# R=0.835	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.84	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.845	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.85	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.855	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.86	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.865	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.87	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.875	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.88	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.885	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.89	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.895	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.9	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.905	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.91	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.915	 M=4 	 clusters:1 	 outliers:3	['ki+egészül', 'ki+kap', 'ki+terjed']
# R=0.92	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.925	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.93	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.935	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.94	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.945	 M=4 	 clusters:1 	 outliers:2	['ki+egészül', 'ki+kap']
# R=0.95	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.955	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.96	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.965	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.97	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.975	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.98	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.985	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.99	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']
# R=0.995	 M=4 	 clusters:1 	 outliers:1	['ki+egészül']

# %%
# with verbal modifier 'el': best outliers as idioms with M=2, R=0.55
# with verbal modifier 'ki': best outliers as idioms with M=2, R=0.54
M = 2
R = 0.54
db = DBSCAN(eps=R, min_samples=M)
db.fit(x)
labels = db.labels_

data[labels != -1].to_csv(outputFile, sep='\t', index=False)
data[labels == -1].to_csv(outputFile2, sep='\t', index=False)

# %%
print("idioms")
data[labels == -1]
# Out:
# idioms
#    pvform    lemma         pvv mood cau pot        PV    CP_cnd        CP_imp  \
# 8      ki   bocsát   ki+bocsát  ind   -   - -0.870730  0.001191  2.302676e-03
# 11     ki    derül    ki+derül  ind   -   - -0.305946 -0.009006  1.895196e-03
# 16     ki  egészül  ki+egészül  ind   -   - -0.435667 -0.006000 -1.666667e-03
# 23     ki    fejez    ki+fejez  ind   -   + -0.432273 -0.015312 -2.355713e-03
# 35     ki    indul    ki+indul  ind   -   - -0.958697  0.000411 -1.518487e-04
# 36     ki       ír       ki+ír  ind   -   - -0.714350  0.013204  1.859194e-03
# 43     ki      kap      ki+kap  ind   -   - -0.352919  0.001317  4.162995e-03
# 48     ki      köt      ki+köt  ind   -   - -0.661990  0.004212 -6.756574e-08
# 57     ki    merül    ki+merül  ind   -   - -0.462374 -0.005085  8.484093e-04
# 61     ki      néz      ki+néz  ind   -   - -0.845098 -0.012997  2.807477e-03
# 62     ki       nő       ki+nő  ind   -   - -0.626895 -0.003676  3.289775e-04
# 74     ki   számít   ki+számít  ind   -   - -0.508130 -0.011352 -4.198102e-04
# 78     ki     tart     ki+tart  ind   -   - -0.113003 -0.003011 -1.023741e-03
# 79     ki   terjed   ki+terjed  ind   -   - -0.464610 -0.002362 -8.080992e-05
# 81     ki     tesz     ki+tesz  ind   -   - -0.888976  0.003275  1.922408e-03
# 84     ki    tűnik    ki+tűnik  ind   -   - -0.286145  0.005488  1.389246e-03
# 91     ki   veszik   ki+veszik  ind   -   - -0.168734 -0.012407 -8.684864e-03
# 94     ki      von      ki+von  ind   -   - -0.490433 -0.003047  5.087389e-04
#
#       CP_ind  ...       ÉRT      KÉNT       KOR      SZOR     NKÉNT       ADP  \
# 8  -0.081851  ...  0.000985 -0.001381 -0.002281  0.000000 -0.009374 -0.049106
# 11 -0.070393  ... -0.000231  0.001895 -0.000955 -0.000129  0.000856  0.042850
# 16  0.120000  ... -0.001000 -0.005667 -0.003333  0.000000 -0.002667  0.247000
# 23 -0.179034  ... -0.005889 -0.014134 -0.001178  0.000000 -0.001178  0.077503
# 35  0.076356  ...  0.028449  0.021456  0.023747  0.000158  0.009019  0.113728
# 36  0.224929  ... -0.003386  0.001666 -0.003019  0.000148 -0.000013 -0.075274
# 43  0.042660  ...  0.022259 -0.010238  0.003362  0.000000  0.004361 -0.000908
# 48 -0.019288  ... -0.001748 -0.007831 -0.006979  0.000000  0.000871 -0.047404
# 57  0.004726  ...  0.001859  0.006043  0.005424  0.000000  0.000696  0.068333
# 61  0.030436  ...  0.000140 -0.002201 -0.000467 -0.000013  0.000874  0.022080
# 62  0.012835  ...  0.000559 -0.002231  0.000700 -0.000163  0.007320  0.072773
# 74 -0.001683  ...  0.000679 -0.006453 -0.003292  0.000000 -0.002755  0.043729
# 78 -0.012530  ...  0.000876  0.013765  0.005478  0.000000  0.001090 -0.344882
# 79  0.030532  ...  0.000672  0.014976  0.000105  0.000000  0.002266  0.073404
# 81 -0.045446  ...  0.010619  0.003670 -0.000216  0.000143 -0.003426  0.009078
# 84  0.147893  ...  0.001312 -0.004920 -0.001052  0.000000 -0.000141 -0.022152
# 91  0.073525  ... -0.002481 -0.003722 -0.002481  0.000000  0.039756  0.191391
# 94  0.014885  ...  0.012652 -0.003047 -0.000789  0.000000  0.000926  0.093215
#
#          ADV      FROM        IN        TO
# 8   0.017704 -0.020618 -0.143489  0.803199
# 11  0.107231 -0.268727  0.150619  0.571753
# 16  0.099000 -0.031333  0.121000 -0.043667
# 23  0.478445 -0.027091 -0.073263 -0.023557
# 35  0.135420 -0.346848  0.308444  0.158899
# 36 -0.079066  0.035607 -0.100100 -0.317718
# 43  0.014521 -0.376457 -0.348851 -0.201697
# 48 -0.173720  0.005469 -0.525061  0.388380
# 57  0.011311  0.007297 -0.231880  0.674036
# 61 -0.403235  0.002161 -0.062503  0.112358
# 62  0.042765 -0.176597  0.086527  0.155527
# 74  0.020713 -0.043085 -0.006418  0.211104
# 78 -0.088099  0.058683 -0.181677 -0.079343
# 79  0.139816  0.220941  0.240432 -0.475365
# 81  0.001899 -0.010341 -0.074277  0.077278
# 84  0.415988 -0.522218 -0.017081  0.024984
# 91 -0.107671 -0.420542  0.083396  0.401284
# 94 -0.051066 -0.783797  0.043289  0.378963
#
# [18 rows x 38 columns]
